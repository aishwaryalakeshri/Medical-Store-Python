# %%
#Project Purpose : 
#Medical Store Management System Software has features such as stock maintenance, automatic updating of records to add medicines
#also to make changes in stored information of medicines with billing function. 
#The software is beneficial because it can reduce daily effort wage and labor numbers as this task can now be left to the system.
#This Software also display data related to Expiry Date details which can be viewed as per the requirement , also used to view Stock Distribution.
#The system is built on Python Programming language , Pandas , Visualization.







#Program :

import pickle
#To add medicine and store data by using File Handling
f=open("Medicinelist.txt","w+")
f.write("This is Medicine List :\n")
listMed=["GLYCOMET \n","CROCIN \n", "ACTION500 \n", "ZAVAMET \n" , "OMEN CT \n"]
f.writelines(listMed)
f.close()

#"All Information" Text file stores all data present or executed in the program

#To add medicine list in 'All Info' file by using file handling
n=open("All Information.txt","w+")      #All Info File is created and data is stored in to it
n.write("This is Medicine List :\n")
listMed=["GLYCOMET \n","CROCIN \n", "ACTION500 \n", "ZAVAMET \n" , "OMEN CT \n"]
n.writelines(listMed)
n.close()

#To add customer and store data by using File Handling
c=open("Customerlist.txt","w+")
c.write("This is Customer List :\n")
customerList=["ASH \n","RIYA \n", "RITU \n", "RAJU \n" , "SANJU \n"]
c.writelines(customerList)
c.close()

#To add customer list in 'All Info' file by using file handling
n=open("All Information.txt","a+")
n.write("\nThis is Customer List :\n")
customerList=["ASH \n","RIYA \n", "RITU \n", "RAJU \n" , "SANJU \n"]
n.writelines(customerList)
n.close()

#To add medicine info and store data by using File Handling
i=open("Medicineinfo.txt","w+")
i.write("Medicine informations are as below:\n")
i.write("GLYCOMET & ZAVAMET are for dibetic patients as per sugar level in patient's body.\n")
i.write("CROCIN & ACTION500 are for normal fevers.\n")
i.write("OMEN CT is for patients having High Blood Pressure.\n")
i.close()


#To add medicine info in 'All Info' file by using file handling
n=open("All Information.txt","a+")
n.write("\nMedicine informations are as below:\n")
n.write("GLYCOMET & ZAVAMET are for dibetic patients as per sugar level in patient's body.\n")
n.write("CROCIN & ACTION500 are for normal fevers.\n")
n.write("OMEN CT is for patients having High Blood Pressure.\n")
n.close()


#To add prices of medicines in 'All Info' file by using file
n=open("All Information.txt","a+")
n.write("\nThis is Price List of Medicines :\n")
priceList=["\n100","\n50","\n75","\n150","\n250"]
n.writelines(priceList)
n.close()


listMed=["GLYCOMET","CROCIN","ACTION500","ZAVAMET","OMEN CT"]
customerList=["ASH","RIYA","RITU","RAJU","SANJU"]


#PRICES OF MEDICINES:      #all are global variables
pglyco=100              
pcroc=50
pact500=75
pzava=150
pomen=250


beforebillingstock=["GLYCOMET:15","CROCIN:30", "ACTION500:25", "ZAVAMET:17" , "OMEN CT:13"]

n=open("All Information.txt","a+")
n.write("\nThis is Stock before Billing :\n")
beforebillingstock=["GLYCOMET:15 \n"  , "CROCIN:30\n" , "ACTION500:25\n"  , "ZAVAMET:17\n"  , "OMEN CT:13\n"]
n.writelines(beforebillingstock)
n.close()


class MedicalStore():                                 #Class is created
        Medical="APEX"
        def __init__(self):                           #Constructor
                print("******WELCOME TO APEX MEDICALS******")
                print("Please select below options for the required Medicine information:")
                print("Option 1 : To View Medicine List")
                print("Option 2 : To Add New Medicine")
                print("Option 3 : To Search Medicine")
                print("Option 4 : To Remove Medicine")
                print("Option 5 : To View Medicine Information")
                print("Option 6 : To Add more Medicine Information")
                print("Option 7 : Billing & Latest Stock Information")
                print("Option 8 : Customerwise Discount")
                print("Option 9 : Before billing stock")
                print("Option 10 : To Add New Customer")
                print("Option 11 : Customer List")
                print("Option 12 : Medical stock details")
                print("Option 13 : Graphical representation of Medical Stock")
                print("Option 14 : Stock Distribution")

                try:
                        Option = int(input("Please Select An Above Option: "))         #Exception Handling
                except ValueError as V:
                        print("That's Not A Number")        
                


                if Option==1:
                         print("Medicines List : \n")
                         for m in listMed:
                                print("=> {}".format(m))

                               
                        
                elif Option==2:                                
                        Extra = input("New Medicine to be added: Y/N ")
                        if Extra=='Y':
                                newMed=input("Enter new medicine : ")
                                if(newMed in listMed):
                                        print("\nThis Medicine {} Already In The Database".format(newMed))
                                else:
                                        with open("Medicinelist.txt","a") as f:             #data stored in 'Medicinelist file' through File Handling
                                                f.write("\n This medicine is added recently:")
                                                f.write("\n=> New Medicine '{}' is Successfully Added \n".format(newMed))
                                                f.write("Updated Medicine List is :")
                                                f.write("\nGLYCOMET \n" "CROCIN \n" "ACTION500 \n" "ZAVAMET \n"  "OMEN CT \n"  "{} \n".format(newMed))

                                        listMed.append(newMed)                             #list is appended
                                        print("\n=> New Medicine {} Successfully Add \n".format(newMed))
                                        print(listMed)
                                        pnew=input("Enter price of New Medicine:")
                                        priceList.append(pnew)
                                        print("\nUpdated pricelist is :")
                                        print(priceList)

                                        with open ("All Information.txt","a+") as n:            #data stored in 'All Info' file through File Handling
                                                n.write("\n This medicine is added recently:")
                                                n.write("\n=> New Medicine '{}' is Successfully Added \n".format(newMed))
                                                n.write("\nUpdated Medicine List is :")
                                                n.write("{}".format(listMed))
                                                n.write("\nUpdated pricelist is :")
                                                n.write("{}".format(priceList))
                                        

                        else:
                                print("No new medicine is added")
                                

                                        
                elif Option==3:
                        searchMed = input("Enter Medicine Name To Search: ")
                        if(searchMed in listMed):
                                print("\n=> Record Found Of Medicine:{}".format(searchMed))
                        else:
                                print("\n=> No Record Found Of Medicine:{}".format(searchMed))
                               

                                addMed=input("Is this Medicine to be added in stocklist :")     #to add medicine if it is not present in medicinelist
                                if addMed=='Y':
                                        with open("Medicinelist.txt","a") as f:                  #to add in Medicinelist file through file Handling
                                                f.write("This medicine is added recently:")
                                                f.write("\n=> New Medicine '{}' is Successfully Added \n".format(searchMed))
                                                listMed.append(searchMed)
                                                print("\n=> New Medicine {} Successfully Add \n".format(searchMed))
                                                print(listMed)
                                                with open ("All Information.txt","a+") as n:        #data stored in 'All Info' file through File Handling
                                                        n.write("This medicine is added recently:")
                                                        n.write("\n=> New Medicine '{}' is Successfully Added \n".format(searchMed))
                                                        n.write("Updated Medicine List is :")
                                                        n.write("{}".format(listMed))
                                                       

                                elif addMed=='N':
                                        print("New Medicine is not added in Stock")
                                        
                                        

                elif Option==4:
                        removeMed = input("Enter Medicine Name To Remove: ")
                        if(removeMed in listMed):
                                listMed.remove(removeMed)               #list remove func
                                print("\n=> Medicine {} Successfully Deleted \n".format(removeMed))
                                print(listMed)

                                with open ("All Information.txt","a+") as n:                    #data stored in 'All Info' file through File Handling
                                        n.write("This medicine is removed recently:")
                                        n.write("\n=> This Medicine '{}' is Successfully Removed from Stock \n".format(removeMed))
                                        n.write("Updated Medicine List is :")
                                        n.write("{}".format(listMed))
                        else:
                                print("\n=> No Record Found of This Medicine {}".format(removeMed))




                elif Option==5:
                        i=open("Medicineinfo.txt","r")                 #to view medicine info
                        data=i.readlines()
                        print(data)
                        for j in data:
                                print(j)
                        i.close()

                        


                elif Option==6:
                        newInfo=str(input("Enter more info:"))        #to add medicine info by File Handling
                        with open("Medicineinfo.txt","a") as i:
                                        i.write("This medicine info is added recently:")
                                        i.write("\n=> New Info : {}\n".format(newInfo))

                        with open ("All Information.txt","a+") as n:      #data stored in 'All Info' file through File Handling
                                n.write("This medicine info is added recently:")
                                n.write("\n=> New Info : {}\n".format(newInfo))

                        
                        
                               
                elif Option==7:
                        nglyco=int(input("Enter no. of GLYCOMET required: "))
                        ncroc=int(input("Enter no. of CROCIN required: "))
                        nact500=int(input("Enter no. of ACTION500 required:"))
                        nzava=int(input("Enter no. of ZAVAMET required:"))
                        nomen=int(input("Enter no. of OMEN CT required:"))


                        #TOTAL STOCK
                        sglyco=15
                        scroc=30
                        sact500=25
                        szava=17
                        somen=13
                        



                        #Current Stock
                        fglyco=int(sglyco-nglyco)
                        fcroc=int(scroc-ncroc)
                        fact500=int(sact500-nact500)
                        fzava=int(szava-nzava)
                        fomen=int(somen-nomen)

                        if fglyco<1:
                                print("Glycomet not in stock")
                        else:
                                 print("Stock of Glycomet is {}".format(fglyco))

                        if fcroc<1:
                                print("Crocin not in stock")
                        else:
                                print("Stock of Crocin is {}".format(fcroc))
                        if fact500<1:
                                 print("Act500 not in stock")
                        else:
                                print("Stock of Act500 is {}".format(fact500))
                        if fzava<1:
                                print("Zavamet not in stock")
                        else:
                                print("Stock of Zavamet is {}".format(fzava))
                        if fomen<1:
                                      print("Omen CT not in stock")
                        else:
                                print("Stock of Omen CT is {}".format(fomen))
                       
                        if fglyco<1 or fcroc<1 or fact500<1 or fzava<1 or fomen<1:
                                print("Above medicines required quantity not in stock so bill cannot be generated")
                                with open ("All Information.txt","a+") as n:
                                    n.write("Required medicines not in stock , so bill cannot be generated")
    
                        
                        else:
                                #Bill of each Medicine according to its required quantity
                                bglyco=int(pglyco*nglyco)       
                                bcroc=int(pcroc*ncroc)
                                bact500=int(pact500*nact500)
                                bzava=int(pzava*nzava)
                                bomen=int(pomen*nomen)
                                
                                #Total Bill
                                tbill=int(bglyco+bcroc+bact500+bzava+bomen)
                                print("Total bill is: {}".format(tbill))

                                custname1=str(input("Enter Customer Name:"))
                                if(custname1 in customerList):
                                        print("Disc is 20%")
                                        custdisc=tbill*0.80
                                        print("\n=> Record Found Of Customer and Total Discounted price is:{}".format(custdisc))
                                        with open ("All Information.txt","a+") as n:      #data stored in 'All Info' file through File Handling
                                                n.write("Total Stock after billing is :")
                                                n.write("\nGLYCOMET:{} \n"   "CROCIN:{}\n"  "ACTION500:{}\n"   "ZAVAMET:{}\n"   "OMEN CT:{}\n".format((fglyco),(fcroc),(fact500),(fzava),(fomen)))
                                                n.write("Customer name : {}".format(custname1))
                                                n.write("\nTotal billing after disc is : {}".format(custdisc))



                                else:
                                        print("No Record Found Of Customer")
                                        print("No Discount is considered")
                                        print("Total bill is: {}".format(tbill))
                                        with open ("All Information.txt","a+") as n:      #data stored in 'All Info' file through File Handling
                                                n.write("Total Stock after billing is :")
                                                n.write("\nGLYCOMET:{} \n"   "CROCIN:{}\n"  "ACTION500:{}\n"   "ZAVAMET:{}\n"   "OMEN CT:{}\n".format((fglyco),(fcroc),(fact500),(fzava),(fomen)))
                                                n.write("\nTotal billing without disc is : {}".format(tbill))
                                        
                                        

                                BillAgain=input("To bill again Y/N:")
                                if BillAgain=='Y':
                                        print("For Billing Again select the quantity of below Medicines required :")
                                        nglyco=int(input("Enter no. of GLYCOMET required :"))
                                        ncroc=int(input("Enter no. of CROCIN required: "))
                                        nact500=int(input("Enter no. of ACTION500 required:"))
                                        nzava=int(input("Enter no. of ZAVAMET required:"))
                                        nomen=int(input("Enter no. of OMEN CT required:"))

                                        bglyco=int(pglyco*nglyco)
                                        bcroc=int(pcroc*ncroc)
                                        bact500=int(pact500*nact500)
                                        bzava=int(pzava*nzava)
                                        bomen=int(pomen*nomen)


                                        fglyco=int(fglyco-nglyco)
                                        fcroc=int(fcroc-ncroc)
                                        fact500=int(fact500-nact500)
                                        fzava=int(fzava-nzava)
                                        fomen=int(fomen-nomen)

                                        if fglyco<1:
                                                print("Glycomet not in stock")
                                        else:
                                                print("Stock of Glycomet is {}".format(fglyco))

                                        if fcroc<1:
                                                print("Crocin not in stock")
                                        else:
                                                print("Stock of Crocin is {}".format(fcroc))
                                        if fact500<1:
                                                print("Act500 not in stock")
                                        else:
                                                print("Stock of Act500 is {}".format(fact500))
                                        if fzava<1:
                                                print("Zavamet not in stock")
                                        else:
                                                print("Stock of Zavamet is {}".format(fzava))
                                        if fomen<1:
                                                print("Omen CT not in stock")
                                        else:
                                                print("Stock of Omen CT is {}".format(fomen))
                       
                                        if fglyco<1 or fcroc<1 or fact500<1 or fzava<1 or fomen<1:
                                                print("Above medicines required quantity not in stock so bill cannot be generated")
                                                with open ("All Information.txt","a+") as n:
                                                    n.write("\nRequired medicines not in stock , so bill cannot be generated")
                                

                                        else:
                                                #Bill of each Medicine according to its required quantity
                                                bglyco=int(pglyco*nglyco)
                                                bcroc=int(pcroc*ncroc)
                                                bact500=int(pact500*nact500)
                                                bzava=int(pzava*nzava)
                                                bomen=int(pomen*nomen)

                                                #Total Bill 
                                                ttbill=int(bglyco+bcroc+bact500+bzava+bomen)
                                                print("Total bill is: {}".format(ttbill))

                                                custname2=str(input("Enter Customer Name:"))
                                                if(custname2 in customerList):        #for different customer
                                                        print("Disc is 20%")
                                                        custdisc1=ttbill*0.80
                                                        print("\n=> Record Found Of Customer and Total Discounted price is:{}".format(custdisc1))
                                                        if (custname1==custname2):    #for same customer total bill
                                                                print("\n=>Final Total Disc Price for both bills is :{}".format(custdisc+custdisc1))
                                                                with open ("All Information.txt","a+") as n:    #data stored in 'All Info' file through File Handling                                                                     n.write("\nTotal Stock after billing is :")
                                                                        n.write("\nGLYCOMET:{} \n"   "CROCIN:{}\n"  "ACTION500:{}\n"   "ZAVAMET:{}\n"   "OMEN CT:{}\n".format((fglyco),(fcroc),(fact500),(fzava),(fomen)))
                                                                        n.write("\nTotal billing after disc is : {}".format(custdisc+custdisc1))
                                                        else:
                                                                print("Total final bill is: {}".format(ttbill+tbill))
                                                                with open ("All Information.txt","a+") as n:      #data stored in 'All Info' file through File Handling
                                                                        n.write("\nTotal Stock after billing is :")
                                                                        n.write("\nGLYCOMET:{} \n"   "CROCIN:{}\n"  "ACTION500:{}\n"   "ZAVAMET:{}\n"   "OMEN CT:{}\n".format((fglyco),(fcroc),(fact500),(fzava),(fomen)))
                                                                        n.write("\nTotal billing without disc is : {}".format(ttbill+tbill))

                                                else:
                                                        print("No Record Found Of Customer")
                                                        print("No Discount is considered")
                                                        print("bill is: {}".format(ttbill))

                                                        print("Stock of Glycomet is {}".format(fglyco))
                                                        print("Stock of Crocin is {}".format(fcroc))
                                                        print("Stock of Action500 is {}".format(fact500))
                                                        print("Stock of Zavamet is {}".format(fzava))
                                                        print("Stock of Omen CT is {}".format(fomen))
                                                        with open ("All Information.txt","a+") as n:      #data stored in 'All Info' file through File Handling
                                                                n.write("\nTotal Stock after billing is :")
                                                                n.write("\nGLYCOMET:{} \n"   "CROCIN:{}\n"  "ACTION500:{}\n"   "ZAVAMET:{}\n"   "OMEN CT:{}\n".format((fglyco),(fcroc),(fact500),(fzava),(fomen)))
                                                                n.write("Customer name : {}".format(custname2))
                                                                n.write("\nTotal billing after NO disc is : {}".format(ttbill))
                                                        


                                elif BillAgain=='N':
                                        print("No new bill is generated")
                                        print("Stock of Glycomet is {}".format(fglyco))
                                        print("Stock of Crocin is {}".format(fcroc))
                                        print("Stock of Action500 is {}".format(fact500))
                                        print("Stock of Zavamet is {}".format(fzava))
                                        print("Stock of Omen CT is {}".format(fomen))

                                        with open ("All Information.txt","a+") as n:
                                                n.write("Total Stock after billing is :")
                                                n.write("\nGLYCOMET:{} \n"   "CROCIN:{}\n"  "ACTION500:{}\n"   "ZAVAMET:{}\n"   "OMEN CT:{}\n".format((fglyco),(fcroc),(fact500),(fzava),(fomen)))

                                        
                                        
                                            
                                else :
                                        print("Enter proper input")

                                
                    
                elif Option==8:
                        custname=str(input("Enter Customer Name:"))
                        if (custname in customerList):
                                print("Disc is 20%")
                        else:
                                print("No disc offered")

                        with open ("All Information.txt","a+") as n:
                                n.write("Customer for customer list given : 20% disc")

                        
                        

                elif Option==9:
                        for s in beforebillingstock:
                                print("=> {}".format(s))

                                
                elif Option==10:                      #Customer is added by file Handling
                        newCust = input("Enter New Customer: ")
                        if(newCust in customerList):
                                print("\nThis Customer {} Already In The Database".format(newCust))
                        else:
                                with open("CustomerList.txt","a") as c:
                                        c.write("This customer is added recently:")
                                        c.write("\n=> New Customer {} is Successfully Added \n".format(newCust))
  
                                customerList.append(newCust)                    #list is appended
                        print("Updated Customer list is : {}",customerList)
                        with open("All Information.txt","a+") as n:             #data stored in 'All Info' file through File Handling
                                n.write("This customer is added recently:")
                                n.write("\n=> New Customer : {} is Successfully Added \n".format(newCust))
                                n.write("Updated Customer List : ")
                                n.write("\n{}".format(customerList))


                elif Option==11:
                        print("CustomerList : {}",customerList)
                        
                
                elif Option==12:                           #Medical stock details uploaded by Pandas
                    import pandas as pd
                    details=pd.read_csv("Medical stock details.csv")
                    print(details)
                    
                elif Option==13:                           #Data visualization 
                    import matplotlib.pyplot as plt
                    import pandas as pd
                    dataframe=pd.read_csv("Medical stock details 1.csv")
                    x = dataframe.Name
                    y1 = dataframe.YesterdaySell
                    y2 = dataframe.TodaySell
                    plt.title("Sale of 2 days")
                    plt.xlabel("Medicines")
                    plt.ylabel("Sale")
                    plt.xticks(rotation=20)
                    plt.plot(x,y1,color="green")
                    plt.plot(x,y2,color="red")
                    plt.legend(labels=["Yesterday Sale","Today Sale"])
                    plt.show()
                    
                elif Option==14:
                    import matplotlib.pyplot as plt          #Data visualization
                    labels = ['GLYCOMET', 'CROCIN', 'ACTION500', 'ZAVAMET', 'OMEN CT']
                    sizes = [15,30,25,17,13]   
                    explode = (0.0, 0.6, 0.1, 0, 0.1)  
                    fig1, ax1 = plt.subplots()
                    ax1.pie(sizes,explode=explode, labels=labels, autopct='%1.3f%%',shadow=True, startangle=90)
                    plt.show()
                
                
                elif (Option<1 or Option>14):
                        print("Please Enter Valid Option")                
						

                        
e=MedicalStore()



def runAgain():
        runAgn = input("\nWant To Run Again Y/N: ")
        if runAgn=='Y':
                MedicalStore()
                runAgain()
        elif runAgn=='N':
                print("Thankyou Be Safe")
        else:
                print("Invalid Input")
                print("Program End")

runAgain()


with open("info.txt","wb") as k:                  #to store info by file handling 'Serialization'
        pickle.dump(e,k)
